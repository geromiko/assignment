# %%
import pandas as pd

# %%
alle_land=pd.read_csv('tb01_FaelleGrundtabelleLaender_csv_2015.csv', sep=';', encoding = "ISO-8859-1")

# %%
alle_land.tail()
# Out:
#             1                                                  2  \
# 17557  980100  IuK-Kriminalität im engeren Sinne (SZ: 517500,...
# 17558  980100  IuK-Kriminalität im engeren Sinne (SZ: 517500,...
# 17559  980100  IuK-Kriminalität im engeren Sinne (SZ: 517500,...
# 17560  980100  IuK-Kriminalität im engeren Sinne (SZ: 517500,...
# 17561  980100  IuK-Kriminalität im engeren Sinne (SZ: 517500,...
#
#                                             3       4   5      6     7  \
# 17557                                 Sachsen   1,203  30    171  14.2
# 17558                          Sachsen-Anhalt   1,470  66    128   8.7
# 17559                      Schleswig-Holstein     694  25    101  14.6
# 17560                               Thüringen   1,729  80    120   6.9
# 17561  Bund echte Zählung der Tatverdächtigen  45,793  56  4,539   9.9
#
#             8     9      10     11    12
# 17557     698    58     586     66  11.3
# 17558     640  43.5     485     57  11.8
# ...
